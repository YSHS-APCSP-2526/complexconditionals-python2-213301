# %% [markdown]
# <a href="https://colab.research.google.com/github/YSHS-APCSP-2526/complexconditionals-python2-213301/blob/main/Text_Based_Adventure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Requirements for text based adventure
# 1. You must have at least 2 different "paths" that are at least 4 decisions in length
# 2. Include an element of randomness (from the random library)
# 3. Include a list that is core to the text based adventure
# 4. Include a function that is called within your program that includes a while loop, and a parameter that influences a conditional statement in your function.
# 5. Commented Code.
# 6. A [digital flowchart](https://docs.google.com/document/d/1p2k3wL6gzjYWBuWxwEQptmbbOZZNsQrthlC12SNtYgY/edit?usp=sharing) that follows accepted symbols for representing code. You can use google slides or [draw.io](https://www.drawio.com/) for the flowchart.

# %%
import time
def intro():
    print("You at the vault door and you need to type in the correct 3 digit code- hint= !@#")
    code = input('input code:   ')
    if code=='123':
        print("You have now entered the vault")
        time.sleep(2)
        vault()
def vault():
    print("The valut has gold or cash but the gold is worth more but wil slow you down and you might get caught. select gold or cash")
    choice = input("Type gold or cash")
    if choice == "gold":
      print("You took the gold and must exit thruogh the front lobby")
      lobby()
    if choice == "cash":
      print("You took the cash and can exit way quicker and not get caught move to the vents")
      vents()
def lobby():
    print("You took the gold and are now in the lobby you must type in the sercurity code to not get caught " )
    secuirty_code = input('input sercurity_code')
    if secuirty_code=='67':
      print("You have cleared the cameras so you wont get caught")
      exit_door()
def vents():
  count=3
  correctCode = False
  while correctCode == False and count >0:
    print("You have the cash and will exit through the vents, but the vents have a locked code on them- the hint is the white house adress")
    password=input('input password')
    if password=='1600':
      print("You have opened the vents exit now!")
      break
    else:
      count -= 1
      print("Incorrect. You have ", count, " more guesses")
    if count==0:
      print("GAME OVER YOU HAVE TRIGGERED THE ALARM")
      break
def exit_door():
    count=1
    correctCode= False
    while correctCode == False and count >0:
      print("The exit door requires 3 peices of information to exit, get them wrong and you get caught")
      print("First Riddle is what has 2 hands but cant pick anything up")
      time.sleep(2)
      if password== "clock":
        print("The next riddle is what gets wet while drying")
      if password=="towel":
        print("WOW youve made it to the last riddle to escape, what has a bed but never sleeps")
      if password=="river" or password=="truck":
        print("Congrdualtions you have succesfully completed the BANK HEIST GAME")

# %%
def main():
  intro()

# %%
main()
# Out:
# You at the vault door and you need to type in the correct 3 digit code- hint= !@#
